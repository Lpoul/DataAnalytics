# %% [markdown]
# # Exercise 2.A Using built-in functions
# ## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    for i in range(len(name)):
        if name[i] == " ":
            f_name = name[:i]
            l_name = name[i+1:]
            print(f"Full name: {name}")
            print(f"First name: {f_name}")
            print(f"Last name: {l_name}")

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen','Ken Penn']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores

# %%
def parse_and_display_list_of_names(list_of_names):
    for x in range(len(test_list)):
            names = test_list[x]
            for y in range(len(names)):
                if names[y] == " ":
                   f_name = names[:y]
                   l_name = names[y+1:]
                   print(f"Full name: {names}")
                   print(f"First name: {f_name}")
                   print(f"Last name: {l_name}")

# %%
parse_and_display_list_of_names(test_list)
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores
# Full name: JB Oinonen
# First name: JB
# Last name: Oinonen
# Full name: Ken Penn
# First name: Ken
# Last name: Penn
